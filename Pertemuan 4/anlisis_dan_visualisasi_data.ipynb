# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("Data_penjualan.csv")

# %%
df
# Out:
#     No Customer Code            Customer Name   Tax  Qty Box  Total Weight  \
# 0    1    CTR0500215         Hartono Sidoarjo   PKP     5401         30696
# 1    2    CTR0200412  Login Megastore Bandung  PTKP      745          4889
# 2    3    CTR0200320     Mutiara Super Kichen  PTKP     1313          4920
# 3    4    CTR0300148       Fortuna Yogyakarta  PTKP      416          2396
# 4    5    CTR0300007            Ada Setiabudi  PTKP      456          1892
# 5    6    CTR0300048         Atlanta Ngaliyan  PTKP      806          4773
# 6    7    CTR0500905                    Bares  PTKP      753          4769
# 7    8    CTR0300435   Depo Pelita Purwokerto  PTKP      649          2336
# 8    9    CTR0300242           Progo Depstore  PTKP     1276          6247
# 9   10    CTR0103779            Sabar Ciledug  PTKP      212          1303
# 10  11    CTR0300011               Toko Pusat  PTKP      992          1294
# ...

# %%
df.head(5)
# Out:
#    No Customer Code            Customer Name   Tax  Qty Box  Total Weight  \
# 0   1    CTR0500215         Hartono Sidoarjo   PKP     5401         30696
# 1   2    CTR0200412  Login Megastore Bandung  PTKP      745          4889
# 2   3    CTR0200320     Mutiara Super Kichen  PTKP     1313          4920
# 3   4    CTR0300148       Fortuna Yogyakarta  PTKP      416          2396
# 4   5    CTR0300007            Ada Setiabudi  PTKP      456          1892
#
#    Price Total Qty Box  Price Total Weight Tax Amount  Total Amount  \
# 0            540100000         30696000000        10%   34359710000
# 1             74500000          4889000000         0%    5459850000
# 2            131300000          4920000000         0%    5556430000
# 3             41600000          2396000000         0%    2681360000
# 4             45600000          1892000000         0%    2131360000
#
#          Area
# 0    Surabaya
# 1     Bandung
# 2     Bandung
# 3  Yogyakarta
# 4    Semarang

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   No                   15 non-null     int64
#  1   Customer Code        15 non-null     object
#  2   Customer Name        15 non-null     object
#  3   Tax                  15 non-null     object
#  4   Qty Box              15 non-null     int64
#  5   Total Weight         15 non-null     int64
#  6   Price Total Qty Box  15 non-null     int64
#  7   Price Total Weight   15 non-null     int64
#  8   Tax Amount           15 non-null     object
#  9   Total Amount         15 non-null     int64
#  10  Area                 15 non-null     object
# dtypes: int64(6), object(5)
# memory usage: 1.4+ KB

# %%
df.isnull().sum()
# Out:
# No                     0
# Customer Code          0
# Customer Name          0
# Tax                    0
# Qty Box                0
# Total Weight           0
# Price Total Qty Box    0
# Price Total Weight     0
# Tax Amount             0
# Total Amount           0
# Area                   0
# dtype: int64

# %%
df['Area'].value_counts()
# Out:
# Semarang      4
# Bandung       3
# Surabaya      2
# Yogyakarta    2
# Tangerang     2
# Banyuwangi    1
# Purwokerto    1
# Name: Area, dtype: int64

# %%
df['Tax'].value_counts()
# Out:
# PTKP    12
# PKP      3
# Name: Tax, dtype: int64

# %%
na = df.groupby(['Customer Name', 'Qty Box', 'Area'])

# %%
na.first()
# Out:
#                                             No Customer Code   Tax  \
# Customer Name           Qty Box Area
# Ada Setiabudi           456     Semarang     5    CTR0300007  PTKP
# Atlanta Ngaliyan        806     Semarang     6    CTR0300048  PTKP
# Bares                   753     Banyuwangi   7    CTR0500905  PTKP
# Depo Pelita Purwokerto  649     Purwokerto   8    CTR0300435  PTKP
# Fortuna Yogyakarta      416     Yogyakarta   4    CTR0300148  PTKP
# Hartono Sidoarjo        5401    Surabaya     1    CTR0500215   PKP
# Login Megastore Bandung 745     Bandung      2    CTR0200412  PTKP
# Modern Elektronik       241     Semarang    12    CTR0300275  PTKP
# Mutiara Super Kichen    1313    Bandung      3    CTR0200320  PTKP
# Perdana KTI             378     Surabaya    15    CTR0500343  PTKP
# Progo Depstore          1276    Yogyakarta   9    CTR0300242  PTKP
# Sabar Ciledug           212     Tangerang   10    CTR0103779  PTKP
# ...

# %%
df['Tax Amount'].value_counts()
# Out:
# 0%     12
# 10%     3
# Name: Tax Amount, dtype: int64

# %%
total = df['Total Amount'].sum()

# %%
total
# Out:
# 79526700000

# %%
df['Qty Box'].sum()
# Out:
# 13960

# %%
sns.boxplot(x="Area", y="Qty Box", data=df)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   No                   15 non-null     int64
#  1   Customer Code        15 non-null     object
#  2   Customer Name        15 non-null     object
#  3   Tax                  15 non-null     object
#  4   Qty Box              15 non-null     int64
#  5   Total Weight         15 non-null     int64
#  6   Price Total Qty Box  15 non-null     int64
#  7   Price Total Weight   15 non-null     int64
#  8   Tax Amount           15 non-null     object
#  9   Total Amount         15 non-null     int64
#  10  Area                 15 non-null     object
# dtypes: int64(6), object(5)
# memory usage: 1.4+ KB

# %%
df.plot(kind="scatter", x="Total Weight", y="Qty Box")
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='Total Weight', ylabel='Qty Box'>

# %%
sns.FacetGrid(df, hue="Area", height=5) \
   .map(plt.scatter, "Total Weight", "Qty Box") \
   .add_legend()
plt.show()

# %%
g = df.groupby(['Area', 'Qty Box', 'Total Weight'])
g.first()
# Out:
#                                  No Customer Code            Customer Name  \
# Area       Qty Box Total Weight
# Bandung    194     1283          13    CTR0200400       Sehati Indo Dua CV
#            745     4889           2    CTR0200412  Login Megastore Bandung
#            1313    4920           3    CTR0200320     Mutiara Super Kichen
# Banyuwangi 753     4769           7    CTR0500905                    Bares
# Purwokerto 649     2336           8    CTR0300435   Depo Pelita Purwokerto
# Semarang   241     1447          12    CTR0300275        Modern Elektronik
#            456     1892           5    CTR0300007            Ada Setiabudi
#            806     4773           6    CTR0300048         Atlanta Ngaliyan
#            992     1294          11    CTR0300011               Toko Pusat
# Surabaya   378     1624          15    CTR0500343              Perdana KTI
#            5401    30696          1    CTR0500215         Hartono Sidoarjo
# ...

# %%
df.drop("No", axis=1).boxplot(by="Area", figsize=(12, 6))
plt.show()

# %%
f,ax = plt.subplots(figsize=(18, 18))
sns.heatmap(df.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
plt.show()

# %%
# Scatter Plot 
# x = attack, y = defense
df.plot(kind='scatter', x='Area', y='Total Amount',alpha = 0.5,color = 'red')
plt.xlabel('Area')              # label = name of label
plt.ylabel('Total Amount')
plt.title('Laba Bersih per Area')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# Text(0.5, 1.0, 'Laba Bersih per Area')
